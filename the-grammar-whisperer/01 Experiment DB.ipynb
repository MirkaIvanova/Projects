# %%
import sys
import os
import importlib
from importlib import reload
from importlib import import_module


# def remount(modules=[]):
#     from google.colab import drive
#     drive.mount('/content/drive', force_remount=True)

#     for module in modules:
#         import_module(module)
# remount()

root_dir =    "/content/drive/MyDrive/Colab Notebooks/bg"
helpers_dir = "/content/drive/MyDrive/Colab Notebooks/bg/helpers"

if root_dir not in sys.path:
    sys.path.append(root_dir)
    sys.path.append(helpers_dir)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2b1f88c40a7d> in <cell line: 6>()
#       4 from importlib import reload
#       5 from importlib import import_module
# ----> 6 from gd_tools import remount1
#       7
#       8 # def remount(modules=[]):
#
# ModuleNotFoundError: No module named 'gd_tools'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
remount1(['gd_tools'])
# import gd_tools
# reload(gd_tools)

from gd_tools import ls
ls(helpers_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1718d4f25770> in <cell line: 1>()
# ----> 1 remount1(['gd_tools'])
#       2 # import gd_tools
#       3 # reload(gd_tools)
#       4
#       5 from gd_tools import ls
#
# NameError: name 'remount1' is not defined

# %%
# !ls -al drive/MyDrive/Colab\ Notebooks/bg/helpers
# Out:
# total 8
# -rw------- 1 root root  440 Jan 14 14:43 gdrive_init.py
# -rw------- 1 root root 2085 Jan 14 16:56 gd_tools.py
# drwx------ 2 root root 4096 Jan 14 16:30 __pycache__
# -rw------- 1 root root   76 Jan 14 14:45 tools.py

# %%
remount(['gd_tools'])
ls(root_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-65d6b736eb5c> in <cell line: 1>()
# ----> 1 remount(['gd_tools'])
#       2 ls(root_dir)
#
# NameError: name 'remount' is not defined
